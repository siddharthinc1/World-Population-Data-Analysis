# %% [markdown]
# # Data Collection

# %%
import pandas as pd

# %% [raw]
# # Collected data from various sources such as kaggle to obtain a compresenhive dataset for analysis.

# %%
df = pd.read_csv("D:\Data Analyst\DataSet\world_population_data.csv")
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %% [markdown]
# # Data Cleaning

# %% [raw]
# # Renamed column's name to understand overall structure of the DataFrame.

# %%
df = df.rename(columns={'rank':'Rank','cca3':'Abbrev.','country':'Country','continent':'Continent','area (km²)':'Area (km²)','density (km²)':'Density (km²)',
                        'growth rate':'Growth rate','world percentage':'World percentage'})
df.columns
# Out:
# Index(['Rank', 'Abbrev.', 'Country', 'Continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'Area (km²)', 'Density (km²)',
#        'Growth rate', 'World percentage'],
#       dtype='object')

# %% [raw]
# # Meticuously cleaned the data to identify missing values from the DataFrame.

# %%
df = df.dropna(axis=0)
df

# %%
df1 = pd.read_csv("D:\Data Analyst\DataSet\world_population_data1.csv")
df1
# Out:
#      Unnamed: 0  Rank Abbrev.           Country      Continent  \
# 0             0     1     IND             India           Asia
# 1             1     2     CHN             China           Asia
# 2             2     3     USA     United States  North America
# 3             3     4     IDN         Indonesia           Asia
# 4             4     5     PAK          Pakistan           Asia
# ..          ...   ...     ...               ...            ...
# 229         229   230     MSR        Montserrat  North America
# 230         230   231     FLK  Falkland Islands  South America
# 231         231   232     NIU              Niue        Oceania
# 232         232   233     TKL           Tokelau        Oceania
# 233         233   234     VAT      Vatican City         Europe
#
#      2023 population  2022 population  2020 population  2015 population  \
# 0         1428627663       1417173173       1396387127       1322866505
# ...

# %% [raw]
# # Removed unwanted columns from the DataFrame.

# %%
df1 = df1.drop(columns=['Unnamed: 0'], axis=1)
df1
# Out:
#      Rank Abbrev.           Country      Continent  2023 population  \
# 0       1     IND             India           Asia       1428627663
# 1       2     CHN             China           Asia       1425671352
# 2       3     USA     United States  North America        339996563
# 3       4     IDN         Indonesia           Asia        277534122
# 4       5     PAK          Pakistan           Asia        240485658
# ..    ...     ...               ...            ...              ...
# 229   230     MSR        Montserrat  North America             4386
# 230   231     FLK  Falkland Islands  South America             3791
# 231   232     NIU              Niue        Oceania             1935
# 232   233     TKL           Tokelau        Oceania             1893
# 233   234     VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %% [raw]
# # Exported cleaned DataFrame to the DataFrame.

# %%
df1.to_csv('D:\Data Analyst\Projects\Analysis of World Population Data\world_population_data1.csv')
